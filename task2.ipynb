# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Titanic-Dataset.csv")
# Summary statistics of numerical features
summary = df.describe().T  
summary['median'] = df.median(numeric_only=True)
print(summary)
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max    median
# PassengerId  891.0000  446.0000
# Survived       1.0000    0.0000
# Pclass         3.0000    3.0000
# Age           80.0000   28.0000
# SibSp          8.0000    0.0000
# Parch          6.0000    0.0000
# Fare         512.3292   14.4542

# %%
num_cols = ['Age', 'Fare', 'SibSp', 'Parch']

# Histograms
df[num_cols].hist(bins=20, figsize=(10, 6))
plt.suptitle('Histograms of Numerical Features')
plt.tight_layout()
plt.show()

# Boxplots
plt.figure(figsize=(12, 8))
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
# Correlation matrix
corr = df.corr(numeric_only=True)
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# Pairplot
sns.pairplot(df[['Age', 'Fare', 'SibSp', 'Parch', 'Survived']], hue='Survived')
plt.suptitle('Pairplot of Selected Features', y=1.02)
plt.show()

# %%
# Example: Boxplot of Fare by Survival
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title('Fare Distribution by Survival')
plt.show()

# Example: Age distribution by survival
sns.histplot(data=df, x='Age', hue='Survived', kde=True, element="step")
plt.title('Age Distribution by Survival')
plt.show()

# %%
# Inference 1: Fare vs Survival
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title('Survival vs Fare')
plt.show()
print("➡ Passengers who paid higher fares were more likely to survive.")

# Inference 2: Age vs Survival
sns.histplot(data=df, x='Age', hue='Survived', kde=True, element="step")
plt.title('Age Distribution by Survival')
plt.show()
print("➡ Younger passengers (especially children) had higher survival rates.")

# Inference 3: Pclass vs Survival
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Passenger Class vs Survival')
plt.show()
print("➡ First class passengers had a much higher chance of survival than third class.")

# Inference 4: Sex vs Survival
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title('Sex vs Survival')
plt.show()
print("➡ Females had a significantly higher survival rate than males.")

# Inference 5: SibSp (siblings/spouses) vs Survival
sns.boxplot(x='Survived', y='SibSp', data=df)
plt.title('Survival vs Number of Siblings/Spouses Aboard')
plt.show()
print("➡ Having 1–2 family members aboard increased survival chances; large families had lower survival.")
# Out:
# ➡ Passengers who paid higher fares were more likely to survive.
# ➡ Younger passengers (especially children) had higher survival rates.
# ➡ First class passengers had a much higher chance of survival than third class.
# ➡ Females had a significantly higher survival rate than males.
# ➡ Having 1–2 family members aboard increased survival chances; large families had lower survival.
